# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url1 = './data/processed/fixed_price.csv'
url2 = './data/processed/indexed_price.csv'
url3 = './data/processed/indexed_price_power.csv'

# %%
df_fixed = pd.read_csv(url1)
df_indexed_price = pd.read_csv(url2)
df_indexed_price_power = pd.read_csv(url3)

# %%
df_fixed
# Out:
#        SISTEMA      CIA PRODUCTO          PRODUCTO_CIA TARIFA FEE        P1  \
# 0    PENINSULA  ACCIONA     FIJO                CIERZO  2.0TD   -  0.088121
# 1    PENINSULA  ACCIONA     FIJO               LEVANTE  2.0TD   -  0.071682
# 2    PENINSULA  ACCIONA     FIJO              LEVANTE+  2.0TD   -  0.082641
# 3    PENINSULA  ACCIONA     FIJO              PONIENTE  2.0TD   -  0.071682
# 4    PENINSULA  ACCIONA     FIJO             PONIENTE+  2.0TD   -  0.077162
# ..         ...      ...      ...                   ...    ...  ..       ...
# 902  PENINSULA      ADI     FIJO               ECO ADI  6.1TD   -  0.071138
# 903  PENINSULA      ADI     FIJO  RESIDENCIAL ESPECIAL  2.0TD   -  0.135186
# 904  PENINSULA      ADI     FIJO          ADI SENCILLA  2.0TD   -  0.075022
# 905  PENINSULA      ADI     FIJO          ADI SENCILLA  3.0TD   -  0.038308
# 906  PENINSULA      ADI     FIJO          ADI SENCILLA  6.1TD   -  0.062918
#
#            P2        P3        P4        P5        P6       P1.       P2.  \
# 0    0.019570  0.000000  0.000000  0.000000  0.000000  0.355703  0.304626
# 1    0.003132  0.000000  0.000000  0.000000  0.000000  0.366868  0.315791
# 2    0.014091  0.000000  0.000000  0.000000  0.000000  0.366868  0.315791
# 3    0.003132  0.000000  0.000000  0.000000  0.000000  0.360778  0.309701
# 4    0.008611  0.000000  0.000000  0.000000  0.000000  0.360778  0.309701
# ..        ...       ...       ...       ...       ...       ...       ...
# 902  0.062579  0.036514  0.031673  0.013448  0.011367  0.223107  0.205496
# 903  0.135186  0.000000  0.000000  0.000000  0.000000  0.165071  0.165071
# 904  0.028336  0.000000  0.000000  0.000000  0.000000  0.253546  0.202874
# 905  0.032600  0.010965  0.010011  0.007487  0.005483  0.239604  0.218459
# 906  0.054359  0.028295  0.023454  0.005229  0.003148  0.210616   0.19298
#
#           P3.       P4.       P5.       P6.
# 0    0.265992         0         0         0
# 1    0.277157         0         0         0
# 2    0.277157         0         0         0
# 3    0.271067         0         0         0
# 4    0.271067         0         0         0
# ..        ...       ...       ...       ...
# 902  0.185999  0.169934  0.167387  0.166234
# 903  0.165071         0         0         0
# 904   0.17825         0         0         0
# 905   0.19183  0.171813  0.168778  0.167685
# 906  0.173552  0.157523  0.154953  0.153746
#
# [907 rows x 18 columns]

# %%
df_fixed["CIA"].unique()
# Out:
# array(['ACCIONA', 'AEQ', 'ELEIA', 'ENDESA', 'ENELUZ', 'EVOLVE', 'FACTOR',
#        'GANA', 'IBERDROLA', 'NATURGY', 'PLENITUDE', 'TOTAL', 'ADI'],
#       dtype=object)

# %%
df_indexed_price
# Out:
#         SISTEMA TARIFA      CIA                  MES           FEE        P1  \
# 0      BALEARES  2.0TD  ACCIONA  2023-06-01 00:00:00        Cierzo  0.212767
# 1      BALEARES  2.0TD  ACCIONA  2023-05-01 00:00:00        Cierzo  0.190597
# 2      BALEARES  2.0TD  ACCIONA  2023-04-01 00:00:00        Cierzo  0.190032
# 3      BALEARES  2.0TD  ACCIONA  2023-03-01 00:00:00        Cierzo  0.208748
# 4      BALEARES  2.0TD  ACCIONA  2023-02-01 00:00:00        Cierzo  0.260442
# ...         ...    ...      ...                  ...           ...       ...
# 9664  PENINSULA  6.4TD  CANDELA  2023-09-01 00:00:00  07 / Bi0,012  0.000000
# 9665  PENINSULA  6.4TD  CANDELA  2023-09-01 00:00:00   08 / Bi0,01  0.000000
# 9666  PENINSULA  6.4TD  CANDELA  2023-09-01 00:00:00  09 / Bi0,008  0.000000
# 9667  PENINSULA  6.4TD  CANDELA  2023-09-01 00:00:00  10 / Bi0,006  0.000000
# 9668  PENINSULA  6.4TD  CANDELA  2023-09-01 00:00:00  11 / Bi0,003  0.000000
#
#             P2        P3        P4   P5        P6
# 0     0.165975  0.142781  0.000000  0.0  0.000000
# 1     0.143704  0.120055  0.000000  0.0  0.000000
# 2     0.143135  0.119475  0.000000  0.0  0.000000
# 3     0.161937  0.138661  0.000000  0.0  0.000000
# 4     0.213867  0.191651  0.000000  0.0  0.000000
# ...        ...       ...       ...  ...       ...
# 9664  0.000000  0.158240  0.144112  0.0  0.139823
# 9665  0.000000  0.156240  0.142112  0.0  0.137823
# 9666  0.000000  0.154240  0.140112  0.0  0.135823
# 9667  0.000000  0.152240  0.138112  0.0  0.133823
# 9668  0.000000  0.149240  0.135112  0.0  0.130823
#
# [9669 rows x 11 columns]

# %%
df_indexed_price["MES"].nunique()
# Out:
# 21

# %%
meses = sorted(df_indexed_price["MES"].unique())

# %%
meses
# Out:
# ['2022-01-01 00:00:00',
#  '2022-02-01 00:00:00',
#  '2022-03-01 00:00:00',
#  '2022-04-01 00:00:00',
#  '2022-05-01 00:00:00',
#  '2022-06-01 00:00:00',
#  '2022-07-01 00:00:00',
#  '2022-08-01 00:00:00',
#  '2022-09-01 00:00:00',
#  '2022-10-01 00:00:00',
#  '2022-11-01 00:00:00',
#  '2022-12-01 00:00:00',
#  '2023-01-01 00:00:00',
#  '2023-02-01 00:00:00',
#  '2023-03-01 00:00:00',
#  '2023-04-01 00:00:00',
#  '2023-05-01 00:00:00',
#  '2023-06-01 00:00:00',
#  '2023-07-01 00:00:00',
#  '2023-08-01 00:00:00',
#  '2023-09-01 00:00:00']

# %%
8*6*3
# Out:
# 144

# %%
df_indexed_price['MES'] = pd.to_datetime(df_indexed_price['MES'])

# %%
df_indexed_price_power
# Out:
#         SISTEMA TARIFA      CIA                  MES           FEE        P1  \
# 0      BALEARES  2.0TD  ACCIONA  2023-06-01 00:00:00        Cierzo  0.212767
# 1      BALEARES  2.0TD  ACCIONA  2023-05-01 00:00:00        Cierzo  0.190597
# 2      BALEARES  2.0TD  ACCIONA  2023-04-01 00:00:00        Cierzo  0.190032
# 3      BALEARES  2.0TD  ACCIONA  2023-03-01 00:00:00        Cierzo  0.208748
# 4      BALEARES  2.0TD  ACCIONA  2023-02-01 00:00:00        Cierzo  0.260442
# ...         ...    ...      ...                  ...           ...       ...
# 9664  PENINSULA  6.4TD  CANDELA  2023-09-01 00:00:00  07 / Bi0,012  0.000000
# 9665  PENINSULA  6.4TD  CANDELA  2023-09-01 00:00:00   08 / Bi0,01  0.000000
# 9666  PENINSULA  6.4TD  CANDELA  2023-09-01 00:00:00  09 / Bi0,008  0.000000
# 9667  PENINSULA  6.4TD  CANDELA  2023-09-01 00:00:00  10 / Bi0,006  0.000000
# 9668  PENINSULA  6.4TD  CANDELA  2023-09-01 00:00:00  11 / Bi0,003  0.000000
#
#             P2        P3        P4   P5        P6
# 0     0.165975  0.142781  0.000000  0.0  0.000000
# 1     0.143704  0.120055  0.000000  0.0  0.000000
# 2     0.143135  0.119475  0.000000  0.0  0.000000
# 3     0.161937  0.138661  0.000000  0.0  0.000000
# 4     0.213867  0.191651  0.000000  0.0  0.000000
# ...        ...       ...       ...  ...       ...
# 9664  0.000000  0.158240  0.144112  0.0  0.139823
# 9665  0.000000  0.156240  0.142112  0.0  0.137823
# 9666  0.000000  0.154240  0.140112  0.0  0.135823
# 9667  0.000000  0.152240  0.138112  0.0  0.133823
# 9668  0.000000  0.149240  0.135112  0.0  0.130823
#
# [9669 rows x 11 columns]

# %%
df_indexed_price_power["TARIFA"].nunique()
# Out:
# 6

# %%
sns.heatmap(df_fixed.corr(numeric_only=True), cmap='YlGnBu', annot= True);

# %%
sns.heatmap(df_indexed_price.corr(numeric_only=True), cmap='YlGnBu', annot=True);

# %%
sns.heatmap(df_indexed_price_power.corr(numeric_only=True), cmap='YlGnBu', annot= True);

# %%
df_indexed_price
# Out:
#         SISTEMA TARIFA      CIA        MES           FEE        P1        P2  \
# 0      BALEARES  2.0TD  ACCIONA 2023-06-01        Cierzo  0.212767  0.165975
# 1      BALEARES  2.0TD  ACCIONA 2023-05-01        Cierzo  0.190597  0.143704
# 2      BALEARES  2.0TD  ACCIONA 2023-04-01        Cierzo  0.190032  0.143135
# 3      BALEARES  2.0TD  ACCIONA 2023-03-01        Cierzo  0.208748  0.161937
# 4      BALEARES  2.0TD  ACCIONA 2023-02-01        Cierzo  0.260442  0.213867
# ...         ...    ...      ...        ...           ...       ...       ...
# 9664  PENINSULA  6.4TD  CANDELA 2023-09-01  07 / Bi0,012  0.000000  0.000000
# 9665  PENINSULA  6.4TD  CANDELA 2023-09-01   08 / Bi0,01  0.000000  0.000000
# 9666  PENINSULA  6.4TD  CANDELA 2023-09-01  09 / Bi0,008  0.000000  0.000000
# 9667  PENINSULA  6.4TD  CANDELA 2023-09-01  10 / Bi0,006  0.000000  0.000000
# 9668  PENINSULA  6.4TD  CANDELA 2023-09-01  11 / Bi0,003  0.000000  0.000000
#
#             P3        P4   P5        P6
# 0     0.142781  0.000000  0.0  0.000000
# 1     0.120055  0.000000  0.0  0.000000
# 2     0.119475  0.000000  0.0  0.000000
# 3     0.138661  0.000000  0.0  0.000000
# 4     0.191651  0.000000  0.0  0.000000
# ...        ...       ...  ...       ...
# 9664  0.158240  0.144112  0.0  0.139823
# 9665  0.156240  0.142112  0.0  0.137823
# 9666  0.154240  0.140112  0.0  0.135823
# 9667  0.152240  0.138112  0.0  0.133823
# 9668  0.149240  0.135112  0.0  0.130823
#
# [9669 rows x 11 columns]

# %%
df_indexed_price['MES'] = pd.to_datetime(df_indexed_price['MES'])

# %%
df_indexed_price.set_index('MES', inplace=True)

# %%
df_indexed = df_indexed_price.sort_index()

# %%
df_indexed
# Out:
#               SISTEMA TARIFA      CIA           FEE        P1        P2  \
# MES
# 2022-01-01  PENINSULA  6.1TD      AEQ             3  0.295530  0.268588
# 2022-01-01  PENINSULA  3.0TD    ELEIA          TEE1  0.317499  0.303789
# 2022-01-01  PENINSULA  3.0TD    ELEIA          TEE2  0.316078  0.302368
# 2022-01-01   CANARIAS  3.0TD  ACCIONA   Tramontana+  0.000000  0.302135
# 2022-01-01  PENINSULA  6.1TD   FACTOR             6  0.287759  0.261259
# ...               ...    ...      ...           ...       ...       ...
# 2023-09-01   BALEARES  6.1TD      AEQ            15  0.213005  0.194625
# 2023-09-01   BALEARES  6.1TD      AEQ            20  0.218005  0.199625
# 2023-09-01   BALEARES  6.1TD      AEQ            25  0.223005  0.204625
# 2023-09-01   BALEARES  6.2TD      AEQ           1.5  0.182961  0.167449
# 2023-09-01  PENINSULA  6.4TD  CANDELA  11 / Bi0,003  0.000000  0.000000
#
#                   P3        P4        P5        P6
# MES
# 2022-01-01  0.000000  0.000000  0.000000  0.226828
# 2022-01-01  0.276553  0.265448  0.257369  0.264855
# 2022-01-01  0.275132  0.264026  0.255948  0.263433
# 2022-01-01  0.000000  0.274442  0.000000  0.271088
# 2022-01-01  0.000000  0.000000  0.000000  0.224869
# ...              ...       ...       ...       ...
# 2023-09-01  0.000000  0.000000  0.000000  0.147411
# 2023-09-01  0.000000  0.000000  0.000000  0.152411
# 2023-09-01  0.000000  0.000000  0.000000  0.157411
# 2023-09-01  0.000000  0.000000  0.000000  0.129326
# 2023-09-01  0.149240  0.135112  0.000000  0.130823
#
# [9669 rows x 10 columns]

# %%
df_indexed["TARIFA"].nunique()
# Out:
# 6

# %%
sns.set(style="whitegrid")

# %%
variables_p = ['P1.', 'P2.', 'P3.', 'P4.', 'P5', 'P6.']

# %%
for variable_p in variables_p:
    plt.figure(figsize=(12, 6))
    sns.lineplot(x='MES', y=variable_p, hue='TARIFA', data=df_indexed)
    plt.title(f'{variable_p} por TARIFA')
    plt.xlabel('Fecha')
    plt.ylabel(variable_p)
    plt.legend(title='TARIFA', bbox_to_anchor=(1, 1))
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\adria\Desktop\desafio tripu\DesafioTripulaciones_Sept23_Grupo2_Data\plots_DM.ipynb Cell 27 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/adria/Desktop/desafio%20tripu/DesafioTripulaciones_Sept23_Grupo2_Data/plots_DM.ipynb#X35sZmlsZQ%3D%3D?line=0'>1</a> for variable_p in variables_p:
#       <a href='vscode-notebook-cell:/c%3A/Users/adria/Desktop/desafio%20tripu/DesafioTripulaciones_Sept23_Grupo2_Data/plots_DM.ipynb#X35sZmlsZQ%3D%3D?line=1'>2</a>     plt.figure(figsize=(12, 6))
# ----> <a href='vscode-notebook-cell:/c%3A/Users/adria/Desktop/desafio%20tripu/DesafioTripulaciones_Sept23_Grupo2_Data/plots_DM.ipynb#X35sZmlsZQ%3D%3D?line=2'>3</a>     sns.lineplot(x='MES', y=variable_p, hue='TARIFA', data=df_indexed)
#       <a href='vscode-notebook-cell:/c%3A/Users/adria/Desktop/desafio%20tripu/DesafioTripulaciones_Sept23_Grupo2_Data/plots_DM.ipynb#X35sZmlsZQ%3D%3D?line=3'>4</a>     plt.title(f'{variable_p} por TARIFA')
#       <a href='vscode-notebook-cell:/c%3A/Users/adria/Desktop/desafio%20tripu/DesafioTripulaciones_Sept23_Grupo2_Data/plots_DM.ipynb#X35sZmlsZQ%3D%3D?line=4'>5</a>     plt.xlabel('Fecha')
#
# File c:\Users\adria\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\relational.py:479, in lineplot(data, x, y, hue, size, style, units, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     465 def lineplot(
#     466     data=None, *,
#     467     x=None, y=None, hue=None, size=None, style=None, units=None,
#    (...)
#     475
#     476     # Handle deprecation of ci parameter
#     477     errorbar = _deprecate_ci(errorbar, ci)
# --> 479     p = _LinePlotter(
#     480         data=data,
#     481         variables=dict(x=x, y=y, hue=hue, size=size, style=style, units=units),
#     482         estimator=estimator, n_boot=n_boot, seed=seed, errorbar=errorbar,
#     483         sort=sort, orient=orient, err_style=err_style, err_kws=err_kws,
#     484         legend=legend,
#     485     )
#     487     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     488     p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# File c:\Users\adria\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\relational.py:215, in _LinePlotter.__init__(self, data, variables, estimator, n_boot, seed, errorbar, sort, orient, err_style, err_kws, legend)
#     201 def __init__(
#     202     self, *,
#     203     data=None, variables={},
#    (...)
#     209     # the kind of plot to draw, but for the time being we need to set
#     210     # this information so the SizeMapping can use it
#     211     self._default_size_range = (
#     212         np.r_[.5, 2] * mpl.rcParams["lines.linewidth"]
#     213     )
# --> 215     super().__init__(data=data, variables=variables)
#     217     self.estimator = estimator
#     218     self.errorbar = errorbar
#
# File c:\Users\adria\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_base.py:634, in VectorPlotter.__init__(self, data, variables)
#     629 # var_ordered is relevant only for categorical axis variables, and may
#     630 # be better handled by an internal axis information object that tracks
#     631 # such information and is set up by the scale_* methods. The analogous
#     632 # information for numeric axes would be information about log scales.
#     633 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634 self.assign_variables(data, variables)
#     636 # TODO Lots of tests assume that these are called to initialize the
#     637 # mappings to default values on class initialization. I'd prefer to
#     638 # move away from that and only have a mapping when explicitly called.
#     639 for var in ["hue", "size", "style"]:
#
# File c:\Users\adria\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_base.py:679, in VectorPlotter.assign_variables(self, data, variables)
#     674 else:
#     675     # When dealing with long-form input, use the newer PlotData
#     676     # object (internal but introduced for the objects interface)
#     677     # to centralize / standardize data consumption logic.
#     678     self.input_format = "long"
# --> 679     plot_data = PlotData(data, variables)
#     680     frame = plot_data.frame
#     681     names = plot_data.names
#
# File c:\Users\adria\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_core\data.py:58, in PlotData.__init__(self, data, variables)
#      51 def __init__(
#      52     self,
#      53     data: DataSource,
#      54     variables: dict[str, VariableSpec],
#      55 ):
#      57     data = handle_data_source(data)
# ---> 58     frame, names, ids = self._assign_variables(data, variables)
#      60     self.frame = frame
#      61     self.names = names
#
# File c:\Users\adria\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_core\data.py:232, in PlotData._assign_variables(self, data, variables)
#     230     else:
#     231         err += "An entry with this name does not appear in `data`."
# --> 232     raise ValueError(err)
#     234 else:
#     235
#     236     # Otherwise, assume the value somehow represents data
#     237
#     238     # Ignore empty data structures
#     239     if isinstance(val, Sized) and len(val) == 0:
#
# ValueError: Could not interpret value `P1.` for `y`. An entry with this name does not appear in `data`.

# %%
for variable_p in variables_p:
    plt.figure(figsize=(12, 6))
    sns.lineplot(x='MES', y=variable_p, hue='SISTEMA', data=df_indexed)
    plt.title(f'{variable_p} por SISTEMA')
    plt.xlabel('Fecha')
    plt.ylabel(variable_p)
    plt.legend(title='SISTEMA', bbox_to_anchor=(1, 1))
    plt.show()

# %%
for variable_p in variables_p:
    plt.figure(figsize=(12, 6))
    sns.lineplot(x='MES', y=variable_p, hue='TARIFA', style='SISTEMA', data=df_indexed)
    plt.title(f'{variable_p} por TARIFA y SISTEMA contratado')
    plt.xlabel('Fecha')
    plt.ylabel(variable_p)
    plt.legend(title='TARIFA', bbox_to_anchor=(1, 1))
    plt.show()
