# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("./data/raw/PFMMESES_COM_20231101_20231130.xls")

# %%
df
# Out:
#             Unnamed: 0            Unnamed: 1                Unnamed: 2  \
# 0                  NaN                   NaN                       NaN
# 1                  NaN                   NaN                       NaN
# 2              Periodo  Energía\nfinal \nMWh  Mercado \ndiario \n€/MWh
# 3  2023-11-01 00:00:00          16416873.005                     66.08
#
#                       Unnamed: 3              Unnamed: 4  \
# 0                            NaN                     NaN
# 1                            NaN                     NaN
# 2  Mercado \nintradiario \n€/MWh  Restricciones\n\n€/MWh
# 3                           0.53                   11.59
#
#               Unnamed: 5 Precio final mensual de comercializadores libres  \
# 0                    NaN                                   Noviembre 2023
# 1                    NaN                                              NaN
# 2  Procesos \nOS \n€/MWh                         Pagos capacidad\n\n€/MWh
# ...

# %%
df = pd.read_csv("./data/raw/enero2023.csv",sep=";")

# %%
df
# Out:
#        Fecha Precio mínimo Precio medio aritmético Precio máximo  Unnamed: 4
# 0   01/01/23             0                    6,70         40,07         NaN
# 1   02/01/23         42,00                  112,55        174,74         NaN
# 2   03/01/23        113,63                  138,79        171,18         NaN
# 3   04/01/23         80,23                  115,26        167,29         NaN
# 4   05/01/23         61,97                  109,19        177,98         NaN
# 5   06/01/23         70,00                  104,14        137,73         NaN
# 6   07/01/23          4,16                   23,77         53,42         NaN
# 7   08/01/23          4,16                   10,28         40,00         NaN
# 8   09/01/23          4,20                   85,78        171,62         NaN
# 9   10/01/23         64,30                  109,40        144,74         NaN
# 10  11/01/23          4,16                   83,84        139,02         NaN
# ...
